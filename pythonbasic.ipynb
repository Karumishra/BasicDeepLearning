# %%
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import cv2 
import time

# %%
def show_images(images, dpi = 100, cols = 1, titles = None):    
    assert((titles is None)or (len(images) == len(titles)))    
    n_images = len(images)    
    if titles is None: 
        titles = ['Image (%d)' % i for i in range(1,n_images + 1)]    
        plt.rcParams['figure.dpi'] = dpi    
        fig = plt.figure()    
    for n, (image, title) in enumerate(zip(images, titles)):        
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)        
        if image.ndim == 2:            
            plt.gray()        
        plt.imshow(image)        
        a.set_title(title)    
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)    
    plt.show()    
    plt.rcParams['figure.dpi'] = 72

# %%
palette = np.array( [ [0,0,0],[255,0,0],[0,255,0],[0,0,255],[255,255,255] ] )

# %%
image = np.array( [ [ 0, 1, 2, 0 ],[ 0, 3, 4, 5]  ] )

# %%
img1 = palette[image]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-5b13f9d27f0b> in <module>
# ----> 1 img1 = palette[image]
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
show_images([img1])

# %%
def create_images(noofimages, imgsize=16, colors = 5):    
    imglist = []    
    for j in range(noofimages):        
        img_array_list = []        
        for i in range(imgsize):            
            img_array_list.append(np.random.randint(0, colors, imgsize))        
        image = np.array( img_array_list )        
        img = palette[image]        
        imglist.append(img)    
    return(imglist)

# %%
imgs = create_images(5, imgsize = 28, colors = 4) 
show_images(imgs)

# %%
yy
